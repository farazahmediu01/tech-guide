# %%
from pydantic import BaseModel
from agents import RunContextWrapper

# %%
class TaskManagerContext(BaseModel):
    user_id: int | None = None
    current_project: str | None = None
    tasks_added: int = 0


def get_info(info: TaskManagerContext) -> str:
    return info.model_dump_json()


task_context = TaskManagerContext(user_id=126, current_project="Project Alpha")
output = get_info(task_context)

# %%
output
# Out:
# '{"user_id":126,"current_project":"Project Alpha","tasks_added":0}'
